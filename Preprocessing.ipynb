# %% [markdown]
# ## Some Testing with yt-dlp

# %%
# !pip install yt-dlp
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.1/170.1 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 52.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 85.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 68.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %% [markdown]
# ### Information about `yt-dlp`

# %% [markdown]
# ```
# ydl_opts = {
#     'format': 'bestaudio/best',
#     'extractaudio': True,
#     'audioformat': 'mp3',
#     'outtmpl': '/content/drive/MyDrive/%(title)s.%(ext)s',
#     'postprocessors': [{
#         'key': 'FFmpegExtractAudio',
#         'preferredcodec': 'mp3',
#         'preferredquality': '192',
#     }],
#     'noplaylist': True,
#     'quiet': False,
#     'retries': 5,
#     'cookies': '/path/to/cookies.txt',
#     'writeinfojson': True,
#     'write_subtitles': True,
#     'subtitleslangs': ['en'],
# }
# ```

# %% [markdown]
# ## Testing with a url

# %%
import yt_dlp

url='https://youtu.be/Sjt5R6wlEIk?si=7GQT-276yv2VlWsu'

ydl_opts = {
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'wav',
        'preferredquality': '192',
    }],
    'outtmpl': '1.%(ext)s',
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])
# Out:
# [youtube] Extracting URL: https://youtu.be/Sjt5R6wlEIk?si=7GQT-276yv2VlWsu
# [youtube] Sjt5R6wlEIk: Downloading webpage
# [youtube] Sjt5R6wlEIk: Downloading ios player API JSON
# [youtube] Sjt5R6wlEIk: Downloading player 1f8742dc
# [youtube] Sjt5R6wlEIk: Downloading m3u8 information
# [info] Sjt5R6wlEIk: Downloading 1 format(s): 251
# [download] Destination: 1.webm
# [download] 100% of    5.40MiB in 00:00:01 at 3.76MiB/s
# [ExtractAudio] Destination: 1.wav
# Deleting original file 1.webm (pass -k to keep)

# %%
# !pip install openai-whisper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 37.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
import whisper

model= whisper.load_model('base')
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:01<00:00, 79.1MiB/s]

# %%
result= model.transcribe('/content/1.wav')

print(result['text'])
# Out:
#  I'm on YouTube a lot. For work, for fun, and for learning. It truly is a one-of-a-kind platform that has tons to offer. I gladly pay for a YouTube premium even, not an ad, just trying to emphasize how much I use YouTube. But there are many things wrong with the site, especially when it comes to language learning. Which led me to discover one of my favorite tools that I use all the time and will probably continue to use for a very long time. It's called YT-DLP. Ooh, a very fancy name. I want to show it to you today and try to demystify it a bit since it's fairly technical or at least looks fairly technical. In the recent, it has that reputation is because it's a command line tool. So it looks like something out of a spy movie to a lot of people. But it's actually pretty easy to use. And the reason it uses the command line is because it doesn't need all of the other bells and whistles of a traditional program. Because all it does is download YouTube videos like this one if you wanted.
# ...

# %% [markdown]
# ## Using google developer console API `youtube-vidoes-api`

# %% [markdown]
# ## Setting Up API

# %%
import os
import googleapiclient.discovery

# Set up the YouTube API client
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyAoJKHSiMBBY_Mb-7qQHyKZR1j7lNOn6RA"

youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey=DEVELOPER_KEY)

# %% [markdown]
# - `query:` The search query string.
#
# - `max_results` (optional): The maximum number of results to return, with a default value of 100.
#
# - it creates a request object using `youtube.search().list():`
#
# - The `request.execute()` method is called to execute the search request and retrieve the response.
#
# - The `request.execute()` method is called to execute the search request and retrieve the response.

# %%
def search_videos(query, max_results=100):
    request = youtube.search().list(
        part="snippet",
        q=query,
        type="video",
        maxResults=max_results
    )
    response = request.execute()
    return response.get('items', [])

# %% [markdown]
# `collect_video_data` is to gather video data based on different sentiment categories (positive, negative, neutral). It uses a search function ( `search_videos`) to retrieve video information from a video platform API (like YouTube).
#
# ### Structure
#
# 1. **Queries Dictionary**: It defines three lists of search queries based on sentiment.
#
# 2. **Video Data Storage**: It initializes a dictionary to store video data categorized by sentiment.
#
# 3. **Search Loop**: It iterates through each sentiment category and its associated queries, performing a search for each query and collecting relevant video data.
#
# ### Key Components
# - **`queries`**: A dictionary mapping sentiment categories to search queries.
# - **`video_data`**: A dictionary initialized to hold lists of video data for each sentiment.
# - **Nested Loops**: The outer loop iterates through sentiments, and the inner loop processes each search query.
# - **Data Collection**: For each video result, it extracts the title, description, and video ID, appending this information to the appropriate list in `video_data`.

# %%
def collect_video_data():

    queries = {
        'positive': ['motivational speech', 'success story', 'inspirational talk','Positive message'],
        'negative': ['negative news', 'angry rant', 'critical review'],
        'neutral': ['tutorial', 'product description', 'informational video']
    }

    video_data = {'positive': [], 'negative': [], 'neutral': []}

    for sentiment, q_list in queries.items():
        for query in q_list:
            results = search_videos(query)
            for item in results:
                video_data[sentiment].append({
                    'title': item['snippet']['title'],
                    'description': item['snippet']['description'],
                    'videoId': item['id']['videoId']
                })

    return video_data

video_data = collect_video_data()

# %%
# Print collected video data
for sentiment in video_data:
    print(f"\n{sentiment.capitalize()} videos:")
    for video in video_data[sentiment]:
        print(f"Title: {video['title']}, Video ID: {video['videoId']}")
# Out:
# Positive videos:
# Title: NOTHING CHANGES IF NOTHING CHANGES 2.0 - Best Motivational Speeches, Video ID: nYSbsjw2tx0
# Title: CHANGE YOUR MIND - Motivational Speech Compilation 2024, Video ID: NqI8XeBeECQ
# Title: WATCH THIS EVERYDAY AND CHANGE YOUR LIFE - Denzel Washington Motivational Speech 2023, Video ID: tbnzAVRZ9Xc
# Title: One of the Greatest Speeches Ever | Steve Jobs, Video ID: Tuw8hxrFBH8
# Title: GET UP AND GRIND - Motivational Speech, Video ID: 5f7E4DQG6kk
# Title: SUCCESS IS NEVER AN ACCIDENT - Motivational Speech, Video ID: F4FOMh200QE
# Title: Admiral McRaven Leaves the Audience SPEECHLESS | One of the Best Motivational Speeches, Video ID: TBuIGBCF9jc
# Title: 6 Ways Become Cold  😎❤ Sigma rule | inspirational quotes | motivational quotes #shorts #motivational, Video ID: vxJkBOkeNqE
# Title: 10 Minutes to Start Your Day Right! - Motivational Speech By Oprah Winfrey [YOU NEED TO WATCH THIS], Video ID: Fo6oU4DfdH0
# ...

# %% [markdown]
# ### Writing the data in a json File

# %%
# Save the video data to a JSON file
import json

with open('youtube_video_data.json', 'w') as f:
    json.dump(video_data, f, indent=4)

# %% [markdown]
# ## youtube-transcript-api

# %% [markdown]
# This Api will used the video IDs to get the transcript of the videos

# %%
# !pip install youtube-transcript-api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

def get_transcript(video_id):
  try:
    transcript = YouTubeTranscriptApi.get_transcript(video_id)
    return " ".join([entry['text'] for entry in transcript])

  except Exception as e:
    print(f"Could not retrieve transcript for video ID {video_id}: {e}")
    return None

# %% [markdown]
# ### Update the video data with transcripts

# %%
for sentiment in video_data:
    for video in video_data[sentiment]:
        transcript = get_transcript(video['videoId'])
        video['transcript'] = transcript

# Save the updated video data with transcripts to a JSON file
with open('youtube_video_data_with_transcripts.json', 'w') as f:
    json.dump(video_data, f, indent=4)
# Out:
# Could not retrieve transcript for video ID vxJkBOkeNqE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=vxJkBOkeNqE! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ('en',)
#
# For this video (vxJkBOkeNqE) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - ar ("Arabic (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
# ...

# %% [markdown]
# ### Open the file in read mode

# %%
import json

with open('youtube_video_data_with_transcripts.json', 'r') as f:
    video_data = json.load(f)

# %%
positive_data=video_data["positive"]
negative_data=video_data["negative"]
neutral_data=video_data["neutral"]

# %%
import pandas as pd

positive_df=pd.DataFrame(positive_data)
negative_df=pd.DataFrame(negative_data)
neutral_df=pd.DataFrame(neutral_data)

# %% [markdown]
# ### Labeling the videos

# %%
positive_df['sentiment']=1
negative_df['sentiment']=-1
negative_df['sentiment']=0

# %% [markdown]
# ### checking vidoes without subscript

# %%
print(positive_df.transcript.isna().sum())
print(negative_df.transcript.isna().sum())
print(negative_df.transcript.isna().sum())
# Out:
# 32
# 20
# 20

# %%
positive_df=positive_df.dropna()
negative_df=negative_df.dropna()
neutral_df=neutral_df.dropna()

# %%
print(positive_df.transcript.isna().sum())
print(negative_df.transcript.isna().sum())
print(negative_df.transcript.isna().sum())
# Out:
# 0
# 0
# 0

# %%
positive_df
# Out:
#                                                  title  \
# 0    NOTHING CHANGES IF NOTHING CHANGES 2.0 - Best ...
# 1    CHANGE YOUR MIND - Motivational Speech Compila...
# 2    WATCH THIS EVERYDAY AND CHANGE YOUR LIFE - Den...
# 3       One of the Greatest Speeches Ever | Steve Jobs
# 4               GET UP AND GRIND - Motivational Speech
# ..                                                 ...
# 144  Goalcast&#39;s Top 10 Most Epic Inspirational ...
# 145  Take Action If You Want Changes - President Ob...
# 146  FIND YOURSELF AGAIN || Best Motivational Speec...
# 147  Steve Harvey- Inspirational Speech | Motivatio...
# 149  WATCH THIS EVERY DAY - Motivational Speech By ...
#
#                                            description      videoId  \
# 0    Nothing changes if nothing changes. 2.0. -----...  nYSbsjw2tx0
# 1    When we strive to become better than we are, e...  NqI8XeBeECQ
# 2    WATCH THIS EVERYDAY AND CHANGE YOUR LIFE - Den...  tbnzAVRZ9Xc
# ...
